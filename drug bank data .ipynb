# %%
import sqlite3 as sql
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sqlite3
import pandas as pd
database = "event.db"

conn = sqlite3.connect(database)

df = pd.read_sql("select * from drug", con=conn)
print(df)
df.head()
# Out:
#      index       id                                             target  \
# 0        0  DB01296                 P14780|Q00653|P01375|P01579|P33673
# 1        1  DB09230                                             Q02641
# 2        2  DB05812                                             P05093
# 3        3  DB01195                               Q14524|P35499|Q12809
# 4        4  DB00201  P30542|P29274|Q07343|P21817|BE0004922|P78527|O...
# ..     ...      ...                                                ...
# 567    567  DB01587          P30536|P14867|P18505|Q8N1C3|O14764|P78334
# 568    568  DB00448                                      P20648|P10636
# 569    569  DB00559                                      P25101|P24530
# 570    570  DB04953                        O43526|O43525|P56696|Q9NR82
# 571    571  DB08865                                      Q9UM73|P08581
#
#                                                 enzyme  \
# 0                                        P33261|P05181
# ...

# %%
df_name=df['name']
df_name
list_name=[]
for name in df_name:
    list_name.append(name)
print(list_name)
# Out:
# ['Glucosamine', 'Azelnidipine', 'Abiraterone', 'Flecainide', 'Caffeine', 'Isosorbidemononitrate', 'Argatroban', 'Methotrimeprazine', 'Fluticasonepropionate', 'Cyclosporine', 'Amantadine', 'Nabumetone', 'Aminophylline', 'Mitotane', 'Estradiol', 'Clofarabine', 'Mesoridazine', 'Dantrolene', 'Chloroquine', 'Memantine', 'Cortisoneacetate', 'Baricitinib', 'Levobupivacaine', 'Azacitidine', 'Anagrelide', 'Enzalutamide', 'Etodolac', 'Histamine', 'Ambenonium', 'Methylprednisolone', 'Miconazole', 'Captopril', 'Indapamide', 'Almotriptan', 'Dutasteride', 'Metoclopramide', 'Daunorubicin', 'Amiloride', 'Naproxen', 'Flurazepam', 'Hydralazine', 'Mycophenolatemofetil', 'Amsacrine', 'Bortezomib', 'Maprotiline', 'Diethylcarbamazine', 'Icotinib', 'Ethinylestradiol', 'Haloperidol', 'Doxepin', 'Fexofenadine', 'Danazol', 'Ciprofloxacin', 'Ethanolamineoleate', 'Ivacaftor', 'Fluvastatin', 'Gliclazide', 'Meprobamate', 'Lovastatin', 'Lomustine', 'Erythromycin', 'Midazolam', 'Doxazosin', 'Isradipine', 'Isoniazid
# ...

# %%
df['enzyme']
# Out:
# 0                                          P33261|P05181
# 1                                                 P08684
# 2       P08684|Q06520|P10635|P10632|P05177|P33261|P11712
# 3                                          P10635|P11712
# 4      P20815|P05177|P24462|P08684|P05181|P10632|P117...
#                              ...
# 567                                               P08684
# 568    P33261|P11712|P08684|P04798|P05177|Q16678|P332...
# 569                                        P08684|P11712
# 570            P22309|P35503|P22310|O60656|P11509|P11245
# 571                                 P08684|P20815|P20813
# Name: enzyme, Length: 572, dtype: object

# %%
pip install networkx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_sql("select * from event", con=conn)
print(df)
df.head()
# Out:
#        index      id1        name1      id2        name2  \
# 0          0  DB12001  Abemaciclib  DB01118   Amiodarone
# 1          1  DB12001  Abemaciclib  DB11901  Apalutamide
# 2          2  DB12001  Abemaciclib  DB00673   Aprepitant
# 3          3  DB12001  Abemaciclib  DB00289  Atomoxetine
# 4          4  DB12001  Abemaciclib  DB00188   Bortezomib
# ...      ...      ...          ...      ...          ...
# 37259  37259  DB01149   Nefazodone  DB09048   Netupitant
# 37260  37260  DB01149   Nefazodone  DB00622  Nicardipine
# 37261  37261  DB11828    Neratinib  DB09048   Netupitant
# 37262  37262  DB09048   Netupitant  DB00622  Nicardipine
# 37263  37263  DB00622  Nicardipine  DB00788     Naproxen
#
#                                              interaction
# 0      The risk or severity of adverse effects can be...
# 1      The serum concentration of Abemaciclib can be ...
# 2      The serum concentration of Abemaciclib can be ...
# ...

# %%
df1=df[['id1','name1', 'id2','name2']]

# %%
df1
# Out:
#            id1        name1      id2        name2
# 0      DB12001  Abemaciclib  DB01118   Amiodarone
# 1      DB12001  Abemaciclib  DB11901  Apalutamide
# 2      DB12001  Abemaciclib  DB00673   Aprepitant
# 3      DB12001  Abemaciclib  DB00289  Atomoxetine
# 4      DB12001  Abemaciclib  DB00188   Bortezomib
# ...        ...          ...      ...          ...
# 37259  DB01149   Nefazodone  DB09048   Netupitant
# 37260  DB01149   Nefazodone  DB00622  Nicardipine
# 37261  DB11828    Neratinib  DB09048   Netupitant
# 37262  DB09048   Netupitant  DB00622  Nicardipine
# 37263  DB00622  Nicardipine  DB00788     Naproxen
#
# [37264 rows x 4 columns]

# %%
df1['weight'] = 1

# Keep only drug name columns
df1 = df1[['name1', 'name2', 'weight']]
df1.head()
# Out:
# C:\Users\waqarkhan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          name1        name2  weight
# 0  Abemaciclib   Amiodarone       1
# 1  Abemaciclib  Apalutamide       1
# 2  Abemaciclib   Aprepitant       1
# 3  Abemaciclib  Atomoxetine       1
# 4  Abemaciclib   Bortezomib       1

# %%
import networkx as nx
import pandas as pd

# Generate a networkx graph
G = nx.from_pandas_edgelist(df1, 'name1', 'name2')

# Give the graph a name
G.name = 'Drug Interactions Network'

# Obtain general information of graph
print(nx.info(G))

# Get graph density
density = nx.density(G)
print("Network density:", density)
# Out:
# Name: Drug Interactions Network
# Type: Graph
# Number of nodes: 570
# Number of edges: 37264
# Average degree: 130.7509
# Network density: 0.22979064533037338

# %%
from operator import itemgetter

# Create dictionary to store degrees of nodes
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# Generate sorted list of tuples of drug entity and corresponding degree
sorted_degree = sorted(degree_dict.items(), key=itemgetter(1), reverse=True)

print("Top 20 drugs by degree:")
for d in sorted_degree[:20]:
    print(d)
# Out:
# Top 20 drugs by degree:
# ('Fluvoxamine', 421)
# ('Amiodarone', 412)
# ('Carbamazepine', 406)
# ('Fosphenytoin', 406)
# ('Clotrimazole', 394)
# ('Ketoconazole', 389)
# ('Bortezomib', 387)
# ('Nefazodone', 379)
# ('Cyclosporine', 370)
# ('Apalutamide', 366)
# ('Clemastine', 366)
# ('Diltiazem', 366)
# ('Dihydroergotamine', 361)
# ('Lovastatin', 360)
# ('Lumacaftor', 360)
# ('Dronedarone', 357)
# ('Ceritinib', 355)
# ('Atomoxetine', 354)
# ('Mifepristone', 354)
# ('Dabrafenib', 353)

# %%
G.degree()
max(dict(G.degree()).items(), key = lambda x : x[1])
# Out:
# ('Fluvoxamine', 421)

# %%
import numpy as np
# Get all degree values
sorted_degree_values = [pair[1] for pair in sorted_degree]

# Set fixed bin size
bins = np.arange(0, 450, 2) # fixed bin size

# Plot histogram
plt.xlim([min(sorted_degree_values)-15, max(sorted_degree_values)+15])
plt.hist(sorted_degree_values, bins=bins, alpha=0.5)
plt.title('Node degree distribution (fixed bin size)')
plt.xlabel('degree')
plt.ylabel('count')
plt.show()

# %%
# Get degree centrality (corresponds with degree)
degree_centrality = nx.degree_centrality(G)
degree_centrality = dict(sorted(degree_centrality.items(), key=lambda item: item[1], reverse=True))
degree_centrality
# Out:
# {'Fluvoxamine': 0.7398945518453427,
#  'Amiodarone': 0.7240773286467487,
#  'Carbamazepine': 0.7135325131810193,
#  'Fosphenytoin': 0.7135325131810193,
#  'Clotrimazole': 0.6924428822495606,
#  'Ketoconazole': 0.6836555360281195,
#  'Bortezomib': 0.680140597539543,
#  'Nefazodone': 0.6660808435852372,
#  'Cyclosporine': 0.6502636203866432,
#  'Apalutamide': 0.6432337434094902,
#  'Clemastine': 0.6432337434094902,
#  'Diltiazem': 0.6432337434094902,
#  'Dihydroergotamine': 0.6344463971880492,
#  'Lovastatin': 0.632688927943761,
#  'Lumacaftor': 0.632688927943761,
#  'Dronedarone': 0.6274165202108962,
#  'Ceritinib': 0.6239015817223198,
#  'Atomoxetine': 0.6221441124780316,
#  'Mifepristone': 0.6221441124780316,
#  'Dabrafenib': 0.6203866432337434,
#  'Isradipine': 0.6203866432337434,
#  'Citalopram': 0.6028119507908611,
#  'Aprepitant': 0.5957820738137082,
#  'Clozapine': 0.59402460456942,
#  'Bosentan': 0.5869947275922671,
#  'Isavuconazole': 0.5869947275922671,
# ...

# %%
# Define function to generate Pyvis visualization
def generate_network_viz(df, source_col, target_col, weights, 
                         layout='barnes_hut',
                         central_gravity=0.15,
                         node_distance=420,
                         spring_length=100,
                         spring_strength=0.15,
                         damping=0.96
                         ):
    
    # Generate a networkx graph
    G = nx.from_pandas_edgelist(df, source_col, target_col, weights)
    
    if layout == 'repulsion':
        bgcolor, font_color = '#222222', 'white'
    else:
        bgcolor, font_color = 'white', 'black'
    
    # Initiate PyVis network object
    drug_net = Network(
                       height='700px', 
                       width='100%',
                       bgcolor=bgcolor, 
                       font_color=font_color, 
                       notebook=True
                      )
    
    # Take Networkx graph and translate it to a PyVis graph format
    drug_net.from_nx(G)
    
    # Create different network layout (repulsion or Barnes Hut)
    if layout == 'repulsion':
        drug_net.repulsion(
                            node_distance=node_distance, 
                            central_gravity=central_gravity, 
                            spring_length=spring_length, 
                            spring_strength=spring_strength, 
                            damping=damping
                           )
        
    # Run default Barnes Hut visualization
    else:
        drug_net.barnes_hut(
#                            gravity=-80000, 
#                            central_gravity=central_gravity, 
#                            spring_length=spring_length, 
#                            spring_strength=spring_strength, 
#                            damping=damping, 
#                            overlap=0
                          )      
        
    # Set additional options for the graph (optional)
    # db_net_sm.set_options("""
#             var options = {
#               "edges": {
#                 "color": {
#                   "inherit": true
#                 },
#                 "font": {
#                   "size": 25,
#                   "strokeWidth": 3
#                 },
#                 "scaling": {
#                   "max": 14
#                 },
#                 "smooth": false
#               },
#               "interaction": {
#                 "tooltipDelay": 100
#               }
#             }
#             """)
        
#     # Create neighbour map (Optional for now)
#     sources = df[source_col]
#     targets = df[target_col]
#     weights = df[weights]

#     edge_data = zip(sources, targets, weights)
#     for e in edge_data:
#         src = e[0]
#         dst = e[1]
#         w = e[2]

#         df.add_node(src, src, title=src)
#         df.add_node(dst, dst, title=dst)
#         df.add_edge(src, dst, value=w)

#     # Add neighbor data to node hover data
#     # neighbor_map = df.get_adj_list()

#     # for node in db_net.nodes:
#     #     node['title'] += ' Neighbors:<br>' + '<br>'.join(neighbor_map[node['id']])
#     #     node['value'] = len(neighbor_map[node['id']])

    return drug_net

# %%
# Define list of oral medications for the common diseases
dm_meds = ['Glucosamine', 'Azelnidipine', 'Abiraterone', 'Flecainide', 'Caffeine', 'Isosorbidemononitrate', 'Argatroban', 'Methotrimeprazine', 'Fluticasonepropionate', 'Cyclosporine', 'Amantadine', 'Nabumetone', 'Aminophylline', 'Mitotane', 'Estradiol', 'Clofarabine', 'Mesoridazine', 'Dantrolene', 'Chloroquine', 'Memantine', 'Cortisoneacetate', 'Baricitinib', 'Levobupivacaine', 'Azacitidine', 'Anagrelide', 'Enzalutamide', 'Etodolac', 'Histamine', 'Ambenonium', 'Methylprednisolone', 'Miconazole', 'Captopril', 'Indapamide', 'Almotriptan', 'Dutasteride', 'Metoclopramide', 'Daunorubicin', 'Amiloride', 'Naproxen', 'Flurazepam', 'Hydralazine', 'Mycophenolatemofetil', 'Amsacrine', 'Bortezomib', 'Maprotiline', 'Diethylcarbamazine', 'Icotinib', 'Ethinylestradiol', 'Haloperidol', 'Doxepin', 'Fexofenadine', 'Danazol', 'Ciprofloxacin', 'Ethanolamineoleate', 'Ivacaftor', 'Fluvastatin', 'Gliclazide', 'Meprobamate', 'Lovastatin', 'Lomustine', 'Erythromycin', 'Midazolam', 'Doxazosin', 'Isradipine', 'Isoniazid', 'Estramustine', 'Doxylamine', 'Methamphetamine', 'Estazolam', 'Ephedrine', 'Methimazole', 'Mometasone', 'Esomeprazole', 'Dicoumarol', 'Everolimus', 'Arsenictrioxide', 'Liotrix', 'Decamethonium', 'Imipramine', 'Epinephrine', 'Bexarotene', 'Methylphenidate', 'Fluorometholone', 'Lorazepam', 'Escitalopram', 'Azatadine', 'Flibanserin', 'Dopamine', 'Avanafil', 'Levomilnacipran', 'Doconexent', 'Clemastine', 'Enalapril', 'Folicacid', 'Erlotinib', 'Carmustine', 'Fluphenazine', 'Clomifene', 'Etizolam', 'Lorcaserin', 'Amphetamine', 'Hexobarbital', 'Mitoxantrone', 'Estradiolvalerate', 'Duloxetine', 'Fesoterodine', 'Citalopram', 'Metoprolol', 'Digoxin', 'Cyclobenzaprine', 'Fluorouracil', 'Disopyramide', 'Methadone', 'Fenfluramine', 'Ketoconazole', 'Ipratropiumbromide', 'Guanethidine', 'Dexchlorpheniraminemaleate', 'Fingolimod', 'Droxidopa', 'Dihydroergotamine', 'Ergonovine', 'Cyanocobalamin', 'Benzocaine', 'Cyclophosphamide', 'Cytarabine', 'Itraconazole', 'Etoricoxib', 'Brompheniramine', 'Imatinib', 'Digitoxin', 'Hydroxychloroquine', 'Apixaban', 'Clomipramine', 'Bleomycin', 'Flupentixol', 'Naloxegol', 'Flurbiprofen', 'Moclobemide', 'Alosetron', 'Dextroamphetamine', 'Miltefosine', 'Glyburide', 'Fosphenytoin', 'Nabiximols', 'Frovatriptan', 'Fluvoxamine', 'Medroxyprogesteroneacetate', 'Clenbuterol', 'Aprepitant', 'Estradioldienanthate', 'Naloxone', 'Acetylsalicylicacid', 'Amrubicin', 'Furosemide', 'Molsidomine', 'Entacapone', 'Clonazepam', 'Atropine', 'Flutamide', 'Mefloquine', 'Desipramine', 'Nabilone', 'Ciclesonide', 'Dicyclomine', 'Levothyroxine', 'Nalmefene', 'Mebendazole', 'Benzphetamine', 'Acetazolamide', 'Flunarizine', 'Cevimeline', 'Cerivastatin', 'Flunitrazepam', 'Lenvatinib', 'Mestranol', 'Lercanidipine', 'Morniflumate', 'Eprosartan', 'Agomelatine', 'Menadione', 'Cefazolin', 'Desvenlafaxine', 'Bisoprolol', 'Ethosuximide', 'Lapatinib', 'Cyclizine', 'Carisoprodol', 'Carteolol', 'Etomidate', 'Cladribine', 'Butamben', 'Ethopropazine', 'Canagliflozin', 'Dexmethylphenidate', 'Diclofenac', 'Gefitinib', 'Ceftriaxone', 'Brigatinib', 'Leflunomide', 'Enflurane', 'Levonorgestrel', 'Dinoprostone', 'Doxycycline', 'Halofantrine', 'Lomitapide', 'Mycophenolicacid', 'Betrixaban', 'Desmopressin', 'Dronabinol', 'Carbamazepine', 'Labetalol', 'Asenapine', 'Etoposide', 'Dexlansoprazole', 'Nefazodone', 'Etacrynicacid', 'Ceritinib', 'Macimorelin', 'Gestodene', 'Imiquimod', 'Levofloxacin', 'Levocetirizine', 'Levosalbutamol', 'Cilostazol', 'Aliskiren', 'Losartan', 'Felbamate', 'Hydroxyprogesteronecaproate', 'Armodafinil', 'Felodipine', 'Amitriptyline', 'Exemestane', 'Melatonin', 'Ergotamine', 'Linagliptin', 'Acebutolol', 'Fentanyl', 'Methoxyflurane', 'Naltrexone', 'Isoflurane', 'Acenocoumarol', 'Methazolamide', 'Methyldopa', 'Cysteamine', 'Dobutamine', 'Buprenorphine', 'Diazoxide', 'Arformoterol', 'Allopurinol', 'Dabrafenib', 'Lumiracoxib', 'Irinotecan', 'Methotrexate', 'Albendazole', 'Methylergometrine', 'Clotrimazole', 'Debrisoquin', 'Chenodeoxycholicacid', 'Masoprocol', 'Neratinib', 'Bezafibrate', 'Doxorubicin', 'Cabergoline', 'Eslicarbazepineacetate', 'Balsalazide', 'Clodronicacid', 'Isosorbidedinitrate', 'Decitabine', 'Granisetron', 'Minaprine', 'Aclidinium', 'Ifosfamide', 'Bicalutamide', 'Flunisolide', 'Gemfibrozil', 'Clofibrate', 'Acetylcholine', 'Mefenamicacid', 'Dexfenfluramine', 'Atomoxetine', 'Dabigatranetexilate', 'Lurasidone', 'Guanabenz', 'Ivermectin', 'Amobarbital', 'Apalutamide', 'Chloroprocaine', 'Clotiazepam', 'Chloramphenicol', 'Docetaxel', 'Hydromorphone', 'Cinchocaine', 'Ketoprofen', 'Eplerenone', 'Doxacuriumchloride', 'Chlorpropamide', 'Methsuximide', 'Disulfiram', 'Estradiolbenzoate', 'Chlorphenamine', 'Dienogest', 'Bambuterol', 'Isoflurophate', 'Levodopa', 'Lisuride', 'Benidipine', 'Metyrapone', 'Imidafenacin', 'Meclizine', 'Betamethasone', 'Loratadine', 'Alprenolol', 'Cinnarizine', 'Dorzolamide', 'Ketobemidone', 'Montelukast', 'Bupropion', 'Dosulepin', 'Ezetimibe', 'Allylestrenol', 'Estrone', 'Copanlisib', 'Dolasetron', 'Crisaborole', 'Darifenacin', 'Ibuprofen', 'Cinacalcet', 'Diethylstilbestrol', 'Modafinil', 'Floxuridine', 'Bosutinib', 'Enasidenib', 'Macitentan', 'Loxoprofen', 'Capsaicin', 'Fomepizole', 'Amlodipine', 'Adenosine', 'Methyprylon', 'Candesartancilexetil', 'Mequitazine', 'Diclofenamide', 'Antipyrine', 'Finasteride', 'Isoprenaline', 'Eszopiclone', 'Fenofibrate', 'Chlorpromazine', 'Alfentanil', 'Cyproheptadine', 'Amiodarone', 'Nicardipine', 'Diazepam', 'Famotidine', 'Donepezil', 'Ajmaline', 'Gemcitabine', 'Mirabegron', 'Loperamide', 'Encainide', 'Alfuzosin', 'Acemetacin', 'Maraviroc', 'Calcitriol', 'Chlorzoxazone', 'Aprindine', 'Clozapine', 'Bifonazole', 'Indomethacin', 'Doxercalciferol', 'Galantamine', 'Iloperidone', 'Idarubicin', 'Alogliptin', 'Midodrine', '    Lglutamine', 'Apremilast', 'Lesinurad', 'Hydrocodone', 'Acetaminophen', 'Clopidogrel', 'Atovaquone', 'Adinazolam', 'Melperone', 'Meloxicam', 'Amoxapine', 'Enoxacin', 'Colchicine', 'Aranidipine', 'Niacin', 'Eltrombopag', 'Gabapentin', 'Carbimazole', 'Clonidine', 'Azathioprine', 'Epirubicin', 'Brivaracetam', 'Carbachol', 'Lorpiprazole', 'Nateglinide', 'Clarithromycin', 'Netupitant', 'Nebivolol', 'Drospirenone', 'Estronesulfate', 'Fostamatinib', 'Bendroflumethiazide', 'Diphenhydramine', 'Hydrocortisone', 'Formoterol', 'Lobeglitazone', 'Letrozole', 'Astemizole', 'Diflunisal', 'Midostaurin', 'Cholinesalicylate', 'Cabazitaxel', 'Dronedarone', 'Methylphenobarbital', 'Beclomethasonedipropionate', 'Ketamine', 'Fluoxetine', 'Clofazimine', 'Betaxolol', 'Amylnitrite', 'Budesonide', 'Malathion', 'Dextromethorphan', 'Brimonidine', 'Biperiden', 'Conivaptan', 'Metamizole', 'Azithromycin', 'Anastrozole', 'Bupivacaine', 'Cannabidiol', 'Mexiletine', 'Cisplatin', 'Cholecalciferol', 'Carbinoxamine', 'Diltiazem', 'Naratriptan', 'Econazole', 'Mifepristone', 'Ertugliflozin', 'Neostigmine', 'Methionine', 'Cimetidine', 'Ltryptophan', 'Benazepril', 'Axitinib', 'Calcidiol', 'Aminosalicylicacid', 'Carvedilol', 'Lubiprostone', 'Etonogestrel', 'Lomefloxacin', 'Cyproteroneacetate', 'Cyclopentolate', 'Methyltestosterone', 'Ethylmorphine', 'Acitretin', 'Eletriptan', 'Bepridil', 'Dexamethasone', 'Estradiolcypionate', 'Dasatinib', 'Epinastine', 'Choline', 'Dalfampridine', 'Brinzolamide', 'Codeine', 'Mitiglinide', 'Acetohexamide', 'Hydrocortamate', 'Bumetanide', 'Celiprolol', 'Hydroxyurea', 'Blonanserin', 'Amifostine', 'Fluocinoloneacetonide', 'Clevidipine', 'Isavuconazole', 'Griseofulvin', 'Fluticasonefuroate', 'Lumacaftor', 'Alclometasone', 'Glimepiride', 'Desloratadine', 'Mepyramine', 'Aceclofenac', 'Brexpiprazole', 'Celecoxib', 'Domperidone', 'Amodiaquine', 'Ambrisentan', 'Bromfenac', 'Aminoglutethimide', 'Dexketoprofen', 'Ethanol', 'Dexmedetomidine', 'Ergocalciferol', 'Guanfacine', 'Bivalirudin', 'Hydroxyzine', 'Lidocaine', 'Clobetasolpropionate', 'Aripiprazole', 'Alimemazine', 'Buspirone', 'Morphine', 'Glutethimide', 'Bromocriptine', 'Halothane', 'Alitretinoin', 'Metronidazole', 'Glycerin', 'Dextropropoxyphene', 'Homatropine', 'Capecitabine', 'Azelastine', 'Bromazepam', 'Ethotoin', 'Fospropofol', 'Cocaine', 'Fulvestrant', 'Levomethadylacetate', 'Dapagliflozin', 'Atorvastatin', 'Ibrutinib', 'Methylnaltrexone', 'Clorazepate', 'Lipoicacid', 'Cariprazine', 'Estradiolacetate', 'Miglitol', 'Lamotrigine', 'Cabozantinib', 'Mercaptopurine', 'Apomorphine', 'Abemaciclib', 'Calciumcarbimide', 'Hesperetin', 'Benzatropine', 'Eliglustat', 'Dofetilide', 'Indacaterol', 'Cilnidipine', 'Nelarabine', 'Epoprostenol', 'Irbesartan', 'Mirtazapine', 'Artenimol', 'Ixabepilone', 'Cobimetinib', 'Deutetrabenazine', 'Naldemedine', 'Lornoxicam', 'Efonidipine', 'Cisapride', 'Dacarbazine', 'Glipizide', 'Mersalyl', 'Mianserin', 'Calcipotriol', 'Nandrolonedecanoate', 'Ketazolam', 'Lansoprazole', 'Bosentan', 'Ezogabine', 'Crizotinib']

cardio_meds = ['Captopril', 'Enalapril', 'Lisinopril', 'Perindopril', 'Irbesartan',
               'Losartan', 'Telmisartan', 'Valsartan', 'Candesartan', 'Atenolol', 
               'Bisoprolol', 'Carvedilol', 'Propranolol', 'Amlodipine', 'Diltiazem', 
               'Nifedipine', 'Verapamil', 'Bumetanide', 'Frusemide', 'Isosorbide',
               'Hydrochlorothiazide', 'Spironolactone', 'Isosorbide Dinitrate', 
               'Isosorbide Mononitrate', 'Aspirin', 'Clopidogrel', 'Ticagrelor', 
               'Atorvastatin', 'Rosuvastatin', 'Simvastatin', 'Pravastatin']  

# List of meds with the most interactions
subset_meds_1 = ['Fluvoxamine', 'Amiodarone', 'Carbamazepine']

# Sample drugs for diabetes (Metformin), hyperlipidemia (Simvastatin), and hypertension (Lisinopril)
subset_meds_2 = ['Caffeine', 'Azelnidipine', 'Isosorbidemononitrate']

# %%
# Focus on subset meds
df_db_int_sm = df1.loc[df1['name1'].isin(subset_meds_2) | df1['name2'].isin(subset_meds_2)]
df_db_int_sm = df_db_int_sm.reset_index(drop=True)
df_db_int_sm.head(20)
# Out:
#             name1                  name2  weight
# 0     Abiraterone               Caffeine       1
# 1      Acebutolol  Isosorbidemononitrate       1
# 2   Acenocoumarol               Caffeine       1
# 3   Acetaminophen               Caffeine       1
# 4       Adenosine               Caffeine       1
# 5     Agomelatine               Caffeine       1
# 6     Albendazole               Caffeine       1
# 7       Alfuzosin           Azelnidipine       1
# 8       Aliskiren  Isosorbidemononitrate       1
# 9     Almotriptan               Caffeine       1
# 10      Alosetron               Caffeine       1
# 11     Amifostine  Isosorbidemononitrate       1
# 12      Amiloride  Isosorbidemononitrate       1
# 13  Aminophylline               Caffeine       1
# 14     Amiodarone               Caffeine       1
# 15     Amiodarone  Isosorbidemononitrate       1
# 16  Amitriptyline               Caffeine       1
# 17     Amlodipine  Isosorbidemononitrate       1
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import zipfile
import json
from pyvis.network import Network
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Generate a networkx graph based on subset data
db_subset_net = generate_network_viz(df_db_int_sm, 'name1', 'name2', 'weight', layout='repulsion')

# Display interactive graph
db_subset_net.show('drug_interactions_network_subset_repulsion.html')

# Run the above code chunk in order to display the graph visualization below
# Out:
#         <iframe
#             width="100%"
#             height="700px"
#             src="drug_interactions_network_subset_repulsion.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Generate a networkx graph based on subset data
db_subset_net = generate_network_viz(df_db_int_sm, 'name1', 'name2', 'weight', layout='barnes')

# Display interactive graph
db_subset_net.show('drug_interactions_network_subset_repulsion.html')

# Run the above code chunk in order to display the graph visualization below
# Out:
#         <iframe
#             width="100%"
#             height="700px"
#             src="drug_interactions_network_subset_repulsion.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# Create network for single drug. Use Phenytoin since it has most edges (i.e. involved in most drug interactions)
df_db_phenytoin = df1.loc[df1['name1'].isin(['Fluvoxamine']) | df1['name2'].isin(['Fluvoxamine'])]

# Generate a networkx graph based on subset data
db_net_phenytoin = generate_network_viz(df_db_phenytoin, 'name1', 'name2', 'weight', layout='repulsion', spring_strength=0.05)
db_net_phenytoin.show('drug_interactions_network_phenytoin.html')

# Run the above code chunk in order to display the graph visualization below
# Out:
#         <iframe
#             width="100%"
#             height="700px"
#             src="drug_interactions_network_phenytoin.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
